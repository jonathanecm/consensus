# %%
# Libraries
import pandas as pd
from datetime import datetime

# %%
pot_journals =  pd.read_csv('data/usable_journals.csv', encoding = "ISO-8859-1")
pot_journals.sort_values(['title'])
# Out:
#                                                 title  \
# 0                     American Journal of Mathematics
# 2                       American Journal of Sociology
# 5                              Annales de GÌ©ographie
# 6                                    Annals of Botany
# 7                               Annals of Mathematics
# 10                                Biological Bulletin
# 12  Contributions from the United States National ...
# 15                                 Die Friedens-Warte
# 14             FinanzArchiv / Public Finance Analysis
# 17                          Geographische Zeitschrift
# 18  JahrbÌ_cher fÌ_r NationalÌ¦konomie und Statist...
# 21                       Journal of Political Economy
# 22  Journal of the Elisha Mitchell Scientific Society
# 23      Journal of the New York Entomological Society
# 25                        Political Science Quarterly
# 26  Proceedings of the Academy of Natural Sciences...
# ...
